# %% [markdown]
# <a href="https://colab.research.google.com/github/barbaraavs/ToDo-Resilia/blob/main/TODO_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #<font color ='#DAA520'><b>ToDo 9: Pessoas deixando a empresa 💻</b></font>

# %% [markdown]
# <font size='4'>O gráfico de bolhas a seguir é muito conhecido e foi retirado do livro: <b>Storytelling with Data: Let's Practice!</b>.  As situações propostas no livro podem ser usadas ​​para nos ajudar a entender e praticar várias lições relacionadas à comunicação com dados.</font>
#
# ![Captura de tela 2022-10-18 193107.png](data:image/png;base64,...)

# %% [markdown]
# <font size='4'>Para esse gráfico temos a seguinte situação: Imagine que você seja o Chefe de Gabinete do Chief Marketing Officer (CMO) de uma grande empresa. Seu chefe, o CMO, pediu que você trabalhasse com seu Parceiro de Negócios de Recursos Humanos (HRBP) para entender o que está causando o atrito – pessoas deixando a empresa – em toda a organização de marketing e apresentar suas descobertas. Seu HRBP analisa os dados e envia por e-mail a visualização acima. Passe algum tempo se familiarizando com o gráfico e os dados que ele mostra e, em seguida, conclua as etapas a seguir.</font>
#
#
#
# ---

# %% [markdown]
# <font size='4'>1) O que está sendo mostrado aqui? Escreva um texto explicando os dados. (Dica: imagine que você precisa explicar esse gráfico para o CMO. Escreva sobre como você faria isso em voz alta (fazendo suposições conforme necessário). Esses dados são fáceis ou complicados de falar em sua forma atual?</font>

# %% [markdown]
# <font size='3'>Os dois gráficos em si apresentam dados com relação a entrada e saída de pessoas da empresa, em específico, o que está causando esses atritos e essa evasão. <br> É claro em um primeiro momento que o motivo mais relevante e em comum entre ambas as visualizações é o fator <b>Progressão na Carreira</b>, que se mostra na visualização 1 no âmbito <i>Capacidade de Impacto</i> como <i>Alto</i> (137), e na segunda visualização, como 171.<br>Ainda sobre a segunda visualização (saída), é possível perceber que esse é o único ponto expressivo que se encontra no quadro, diferente da visualização 1, na qual mais dois pontos aparecem: <i>Tipo de Trabalho</i> (128), adotando uma postura mediana para baixo entre a frequencia e a capacidade de impacto, e <i>Realocação</i> (105), que aparece com uma frequência alta, mas com um impacto um pouco menor, quando comparado aos outros dois fatores que foram anteriormente citados.<br><br>Sobre ser dados fáceis ou difíceis de ler em sua forma atual: por serem informações dispostas em um gráfico diferente do padrão (ex: gráfico de barras), são um pouco mais difíceis em sua leitura. Mas, por possuir legendas e instruções, acabam se tornando um pouco mais fácil após um tempo.</font>
#
#
#
# ---

# %% [markdown]
# <font size='4'>2) Que observações você pode fazer a partir desses dados? Coloque três conclusões específicas em palavras (Escreva sentenças completas)</font>

# %% [markdown]
# <font size='3'>Fica muito claro em um primeiro momento quais são os principais pontos que levam uma pessoa a entrar nesta empresa: <i>Progressão de Carreira (137)</i>, <i>Tipo de Trabalho (128)</i> e <i>Realocação (105)</i> e que, desses três pontos, o que mais impacta na hora de desligamentos, é somente um: <i>Progressão na Carreira</i>, que acaba crescendo 34 pontos, quando comparado a ele mesmo, mas no âmbito de contratação.<br><br>O segundo ponto que fica muito evidente é com relação a <i>Realocação</i>: esse fator é o que mais sofre queda quando comparada a entrada/saída de um funcionário de uma empresa. Esse fator tem uma queda de 68 pontos, e caindo seu impacto de Alto para Baixo, deixando claro que este não é um fator que leva as pessoas a se desligarem da empresa.<br><br>O terceiro ponto é com relação ao <i>Tipo de trabalho.</i>Há uma queda de 50 pontos quando comparado a visualização 1, e se mantendo em um âmbito de frequência próximo a Alta. Esse número pode se dar por conta da diferença do escopo do trabalho que foi anunciado, quando comparado ao realizado pelo funcionário no dia-a-dia.</font>
#
#
# ---

# %% [markdown]
# <font size='4'>3) O que não é ideal ou poderia ser evitado na visualização em sua forma atual? Que perguntas você faria ou feedback para quem fez o gráfico? (Ex: suponha que seu HRBP gastou muito tempo criando esse gráfico, como você pode enquadrar seu feedback para que ele não se ofenda?)</font>

# %% [markdown]
# <font size='3'>A visualização poderia ser alterada para uma mais convencional (gráfico de colunas, por exemplo). Isso facilitaria o entendimento do leitor e tornaria a compreensão mais eficaz.<br>Também, a inclusão de datas: sob qual período de tempo os dados estão falando? Não é possível ter essa clareza somente com a visualização que temos.</font>
#
#
# ---

# %% [markdown]
# <font size='4'>4) Vamos visualizar! Invente três maneiras diferentes de mostrar esses dados. quais são algumas vantagens e deficiências de cada uma? Liste-as. (Coloquei o esboço de cada uma no arquivo)</font>

# %% [markdown]
# <font size='3'>Gráfico de Colunas Empilhadas:</font>
#
# ![Captura de tela 2022-10-20 195122.png](data:image/png;base64,...)
#
# <font size='3'>Este é um gráfico de fácil entendimento, possuindo como vantagem maior justamente o entendimento por todos. Como desvantagem, as vezes, por ser justamente uma visualização "padrão", pode ser interpretado de maneira errada ou até mesmo, ignorado.</font>

# %% [markdown]
# <font size='3'>Gráfico de Colunas Clusterizado:</font>
#
# ![Captura de tela 2022-10-20 195737.png](data:image/png;base64,...)
#
# <font size='3'>Assim como o anterior, este gráfico possui fácil entendimento, e permite a comparação de maneira mais fácil ao leitor. Como desvantagem, não é possível representar uma variável contínua, e caso fosse a ideia desta visualização, seria necessário buscar outro gráfico para atender a esta demanda.</font>

# %% [markdown]
# <font size='3'>Gráfico de Pizza:</font>
#
# ![Captura de tela 2022-10-20 200852.png](data:image/png;base64,...)
#
# <font size='3'>Este é um gráfico que permite a rapida interpretação e para comparação. Mas, quando há um volume muito grande de dados, se torna difícil entender o que cada fatia em si quer nos trazer como informação, tornando o mesmo complexo e descartavel.</font>
#
#
#
# ---

# %% [markdown]
# <font size='4'>5) Qual visualização representa melhor os dados e por quê?</font>

# %% [markdown]
# <font size='3'>Gráfico de Colunas Clusterizado. Acredito que esta seja a melhor visualização por já permitir um comparativo em primeiro plano, sendo fácil de entender quais são os dados que estão sendo mostrados e a diferença entre ambos.</font>
#
#
#
# ---

# %% [markdown]
# <font size='4'>6) Baixe os dados e crie a visualização que você acha que representou melhor com a ferramenta de sua preferência (matplotlib, tableau, etc).</font>

# %% [markdown]
# ![Captura de tela 2022-10-20 195737.png](data:image/png;base64,...)
#
#
#
# ---

# %% [markdown]
# <font size='4'>7) O objetivo é pensar  além de simplesmente mostrar dados. Como você pode gerar essas informações em uma história orientada por dados para seu gerente, o CMO.  (Qual é o contexto da história?)</font>

# %% [markdown]
# <font size='3'>Recebemos a informação de que possuímos um número grande de vazão de pessoas em nossa empresa, e precisamos entender o porque disso estar acontecendo. O time de HRBP organizou alguns dados com relação a motivos que podem estar influenciando essa decisão, e precisamos entender o quanto isso acarreta no desligamento dos nossos colaboradores.</font>
#
#
#
# ---
